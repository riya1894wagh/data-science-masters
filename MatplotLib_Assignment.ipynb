# %% [markdown]
# #### Data Science Master's
# ##### Assignment-3
# ###### Tuple, Set & Dict

# %% [markdown]
# ### Q1: What is Matplotlib? Why is it used? Name five plots that can be plotted using the Pyplot module of Matplotlib ?

# %% [markdown]
# Ans : matplotlib is the Most Popular Python Library for Data Visualization and Exploration.Matplotlib is a cross-platform, data visualization and graphical plotting library for Python and its numerical extension NumPy.
#
# Matplotlib is a comprehensive library for creating static, animated, and interactive visualizations in Python. Matplotlib makes easy things easy and hard things possible.
#
# *plots that can be plotted using the pyplot model of matplot lib*:
# * Line plot
# * Histogram
# * Bar Chart
# * Scatter plot
# * Pie charts
# * Boxplot

# %% [markdown]
# Import Matplotlib

# %%
import matplotlib

# %%
# Checking Matplotlib Version
print(matplotlib.__version__)
# Out:
# 3.6.2

# %% [markdown]
# #### *Pyplot*
# Most of the Matplotlib utilities lies under the pyplot submodule, and are usually imported under the plt alias:

# %%
import matplotlib.pyplot as plt

# %%
x = [1,2,3,5,8,8,6,4,7,9,6,8,2,2]
y = [1,5,9,6,3,8,7,5,6,4,5,8,8,6]

# Line Plot

plt.plot(x,y)

# %%
# histogram

plt.hist(x)
# Out:
# (array([1., 3., 1., 1., 0., 1., 2., 1., 3., 1.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
# histogram

plt.hist(x)
# Out:
# (array([1., 3., 1., 1., 0., 1., 2., 1., 3., 1.]),
#  array([1. , 1.8, 2.6, 3.4, 4.2, 5. , 5.8, 6.6, 7.4, 8.2, 9. ]),
#  <BarContainer object of 10 artists>)

# %%
# Bar chart

plt.bar(x,y)
# Out:
# <BarContainer object of 14 artists>

# %%
# Scatter plot

plt.scatter(x,y)

# %%
# Pie chart

plt.pie(x)
plt.show()

# %%
# boxplot
plt.boxplot(x,y)
# Out:
# {'whiskers': [<matplotlib.lines.Line2D at 0x7f0e750943a0>,
# ...
#  'caps': [<matplotlib.lines.Line2D at 0x7f0e750658d0>,
# ...
#  'boxes': [<matplotlib.lines.Line2D at 0x7f0e75094100>],
#  'medians': [<matplotlib.lines.Line2D at 0x7f0e75140fd0>],
#  'fliers': [<matplotlib.lines.Line2D at 0x7f0e751ecbe0>],
#  'means': []}

# %% [markdown]
# ### Q2: What is a scatter plot? Use the following code to generate data for x and y. Using this generated data
# ### plot a scatter plot.
# ### import numpy as np
# ### np.random.seed(3)
# ### x = 3 + np.random.normal(0, 2, 50)
# ### y = 3 + np.random.normal(0, 2, len(x))
#  Note: Also add title, xlabel, and ylabel to the plot.

# %% [markdown]
# Ans: Scatter plots are the graphs that present the relationship between two variables in a data-set. It represents data points on a two-dimensional plane or on a Cartesian system.

# %%
import numpy as np
np.random.seed(3)
x = 3 + np.random.normal(0, 2, 50)
y = 3 + np.random.normal(0, 2, len(x))
plt.scatter(x,y)
plt.title("Scatter Plot")
plt.xlabel("This is my x-axis")
plt.ylabel("This is my y-axis")
# Out:
# Text(0, 0.5, 'This is my y-axis')

# %% [markdown]
# ### Q3: Why is the subplot() function used? Draw four line plots using the subplot() function.
# Use the following data:
#
# import numpy as np
#
# For line 1: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([0, 100, 200, 300, 400, 500])
#
# For line 2: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([50, 20, 40, 20, 60, 70])
#
# For line 3: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([10, 20, 30, 40, 50, 60])
#
# For line 4: x = np.array([0, 1, 2, 3, 4, 5]) and y = np.array([200, 350, 250, 550, 450, 150])

# %% [markdown]
# Ans:
#
#     With the subplot() function you can draw multiple plots in one figure:

# %%
#plot 1 :
x = np.array([0, 1, 2, 3, 4, 5])  
y = np.array([0, 100, 200, 300, 400, 500])
plt.subplot(2, 4, 1)
plt.title("my first plot")
plt.plot(x,y)

#plot 2 :
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([50, 20, 40, 20, 60, 70])
plt.subplot(2, 4, 2)
plt.title("my second plot")
plt.plot(x,y)

#plot 3 :
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([10, 20, 30, 40, 50, 60])
plt.subplot(2, 4, 3)
plt.title("my third plot")
plt.plot(x,y)

#plot 4 :
x = np.array([0, 1, 2, 3, 4, 5])
y = np.array([200, 350, 250, 550, 450, 150])
plt.subplot(2, 4, 4)
plt.title("my fourth plot")
plt.plot(x,y)

plt.show()

# %% [markdown]
# ### Q4: What is a bar plot? Why is it used? Using the following data plot a bar plot and a horizontal bar plot.
# import numpy as np
#
# company = np.array(["Apple", "Microsoft", "Google", "AMD"])
#
# profit = np.array([3000, 8000, 1000, 10000])

# %% [markdown]
# Ans:
#
#     With Pyplot, you can use the bar() function to draw bar graphs:
#
#
# The *bar()* function takes arguments that describes the layout of the bars.
#
# The categories and their values represented by the first and second argument as arrays.
#
# ### *Horizontal Bars*
# If you want the bars to be displayed horizontally instead of vertically, use the barh() function:
# ### *Bar Color*
# The bar() and barh() take the keyword argument color to set the color of the bars:
# ### *Bar Color*
# The bar() and barh() take the keyword argument color to set the color of the bars:
# The barh() takes the keyword argument height to set the height of the bars:

# %%
company = np.array(["Apple", "Microsoft", "Google", "AMD"])

profit = np.array([3000, 8000, 1000, 10000])

plt.barh(company , profit , color = "blue" ,  height = 0.1   )
plt.show()

# %% [markdown]
# ### Q5: What is a box plot? Why is it used? Using the following data plot a box plot.
#
# box1 = np.random.normal(100, 10, 200)
#
# box2 = np.random.normal(90, 20, 200)

# %% [markdown]
# Ans:
# Boxplots are a measure of how well distributed the data in a data set is. It divides the data set into three quartiles. This graph represents the minimum, maximum, median, first quartile and third quartile in the data set.
# t is also useful in comparing the distribution of data across data sets by drawing boxplots for each of them.

# %%
box1 = np.random.normal(100, 10, 200)

box2 = np.random.normal(90, 20, 200)

plt.boxplot(box1)
plt.show()

# %%
plt.boxplot(box2)
plt.show()
